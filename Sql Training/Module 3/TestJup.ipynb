# %%
#this is a practice jupyter notebook 
print("Hello World");
# Out:
# Hello World

# %% [markdown]
# This is notes to look at through the jupyter notebook

# %%
print("hello wordl");
# Out:
# hello wordl

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\DillonGordon\OneDrive - db Engineering\Desktop\SQLTraining\Module 3\Energy US-MTV-STLN2025.csv')
print(df.columns)
df.plot(x='Min Elapsed', y='Net kW/h', kind='line')
plt.show()
# Out:
# Index(['building', 'Min Elapsed', 'Net kW/h', 'energy_accumulator'], dtype='object')
